# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# %%
#Read in the csv
airbnb_df = pd.read_csv('listings_clean_nan.csv')
airbnb_df.head()
# Out:
#    Unnamed: 0       source                                               name  \
# 0           0  city scrape   Home in Kapaau · ★4.94 · Studio · 1 bed · 1 bath
# 1           1  city scrape  Rental unit in Pahala · ★4.56 · 2 bedrooms · 2...
# 2           2  city scrape  Cabin in Mountain View · 1 bedroom · 2 beds · ...
# 3           3  city scrape  Home in Kailua-Kona · 2 bedrooms · 3 beds · 1 ...
# 4           4  city scrape  Rental unit in Waikoloa Village · ★New · 1 bed...
#
#      host_id                                     host_url       host_name  \
# 0   31314577   https://www.airbnb.com/users/show/31314577            Marc
# 1   13268454   https://www.airbnb.com/users/show/13268454        Madaline
# 2  251605183  https://www.airbnb.com/users/show/251605183        Kathleen
# 3  504489199  https://www.airbnb.com/users/show/504489199  Kelly And Zain
# 4  336576760  https://www.airbnb.com/users/show/336576760             Tim
#
#   host_since      host_location  host_response_time host_response_rate  ...  \
# 0  4/16/2015         Waimea, HI      within an hour               100%  ...
# 1  3/18/2014  San Francisco, CA  a few days or more                 0%  ...
# 2  3/27/2019     Kurtistown, HI      within an hour               100%  ...
# 3   3/8/2023    Kailua-Kona, HI      within an hour               100%  ...
# 4  2/16/2020   Myrtle Beach, SC  within a few hours                97%  ...
#
#   review_scores_cleanliness review_scores_checkin review_scores_communication  \
# 0                      4.81                   5.0                        4.88
# 1                      4.56                   5.0                        4.78
# 2                       NaN                   NaN                         NaN
# 3                       NaN                   NaN                         NaN
# 4                       NaN                   NaN                         NaN
#
#    review_scores_location  review_scores_value instant_bookable  \
# 0                    4.88                 4.81                f
# 1                    4.33                 4.44                f
# 2                     NaN                  NaN                t
# 3                     NaN                  NaN                f
# 4                     NaN                  NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              4                                           4
# 1                              1                                           1
# 2                              3                                           1
# 3                              3                                           3
# 4                             79                                          79
#
#   calculated_host_listings_count_private_rooms reviews_per_month
# 0                                            0              1.41
# 1                                            0              0.09
# 2                                            2               NaN
# 3                                            0               NaN
# 4                                            0               NaN
#
# [5 rows x 61 columns]

# %%
# Look at the shape
airbnb_df.shape
# Out:
# (34040, 61)

# %%
# Look at what would drop
airbnb_df.dropna().shape
# Out:
# (0, 61)

# %%
# Look at the columns
airbnb_df.columns
# Out:
# Index(['Unnamed: 0', 'source', 'name', 'host_id', 'host_url', 'host_name',
#        'host_since', 'host_location', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_has_profile_pic',
#        'host_identity_verified', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms_text',
#        'bedrooms', 'beds', 'price', 'minimum_nights', 'maximum_nights',
#        'minimum_minimum_nights', 'maximum_minimum_nights',
#        'minimum_maximum_nights', 'maximum_maximum_nights',
#        'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'calendar_updated',
#        'has_availability', 'availability_30', 'availability_60',
#        'availability_90', 'availability_365', 'calendar_last_scraped',
#        'number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
#Create a Data Frame with needed columns for ML algorithm
airbnb_sh_df = airbnb_df [['host_response_rate','host_acceptance_rate','host_is_superhost',
            'host_identity_verified','price',
            'review_scores_rating','instant_bookable','reviews_per_month']]
airbnb_sh_df.head()
# Out:
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0               100%                  98%                 t
# 1                 0%                   0%                 f
# 2               100%                  93%                 f
# 3               100%                  97%                 t
# 4                97%                  21%                 t
#
#   host_identity_verified    price  review_scores_rating instant_bookable  \
# 0                      t  $175.00                  4.94                f
# 1                      f  $225.00                  4.56                f
# 2                      t  $100.00                   NaN                t
# 3                      t  $102.00                   NaN                f
# 4                      t  $209.00                   NaN                f
#
#    reviews_per_month
# 0               1.41
# 1               0.09
# 2                NaN
# 3                NaN
# 4                NaN

# %%
# Look at counts
airbnb_sh_df.count()
# Out:
# host_response_rate        31487
# host_acceptance_rate      32403
# host_is_superhost         34018
# host_identity_verified    34038
# price                     32748
# review_scores_rating      25869
# instant_bookable          34040
# reviews_per_month         25858
# dtype: int64

# %%
# Drop NA rows
airbnb_sh_df_dna = airbnb_sh_df.dropna()

# %%
# Look at Counts after dropping NAs
airbnb_sh_df_dna.count()
# Out:
# host_response_rate        23548
# host_acceptance_rate      23548
# host_is_superhost         23548
# host_identity_verified    23548
# price                     23548
# review_scores_rating      23548
# instant_bookable          23548
# reviews_per_month         23548
# dtype: int64

# %%
#Look at datatypes
airbnb_sh_df_dna.dtypes
# Out:
# host_response_rate         object
# host_acceptance_rate       object
# host_is_superhost          object
# host_identity_verified     object
# price                      object
# review_scores_rating      float64
# instant_bookable           object
# reviews_per_month         float64
# dtype: object

# %%
# Look at shape
airbnb_sh_df_dna.shape
# Out:
# (23548, 8)

# %%
# Convert host response rate to integer
airbnb_sh_df_dna.host_response_rate = airbnb_sh_df_dna.host_response_rate.str.replace('%','').astype('int')
# Out:
# <ipython-input-12-54c2f90b8817>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   airbnb_sh_df_dna.host_response_rate = airbnb_sh_df_dna.host_response_rate.str.replace('%','').astype('int')

# %%
# Convert host acceptance rate to integer
airbnb_sh_df_dna.host_acceptance_rate = airbnb_sh_df_dna.host_acceptance_rate.str.replace('%','').astype('int')
# Out:
# <ipython-input-13-f5f00195ee1b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   airbnb_sh_df_dna.host_acceptance_rate = airbnb_sh_df_dna.host_acceptance_rate.str.replace('%','').astype('int')

# %%
# Convert price to float
airbnb_sh_df_dna['price'] = airbnb_sh_df_dna['price'].str.replace('$', '').str.replace(',', '').astype('float64')
# Out:
# <ipython-input-14-8c748fc9adf3>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   airbnb_sh_df_dna['price'] = airbnb_sh_df_dna['price'].str.replace('$', '').str.replace(',', '').astype('float64')
# <ipython-input-14-8c748fc9adf3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   airbnb_sh_df_dna['price'] = airbnb_sh_df_dna['price'].str.replace('$', '').str.replace(',', '').astype('float64')

# %%
# Encode Super Host column
airbnb_sh_df_dna['host_is_superhost'] = airbnb_sh_df_dna['host_is_superhost'].replace({'t': 1, 'f': 0})
# Out:
# <ipython-input-15-7d0b6d9b1c51>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   airbnb_sh_df_dna['host_is_superhost'] = airbnb_sh_df_dna['host_is_superhost'].replace({'t': 1, 'f': 0})

# %%
# Encode Host Profile column
# airbnb_sh_df_dna['host_has_profile_pic'] = airbnb_sh_df_dna['host_has_profile_pic'].replace({'t': 1, 'f': 0})

# %%
# Encode Host Identity column
airbnb_sh_df_dna['host_identity_verified'] = airbnb_sh_df_dna['host_identity_verified'].replace({'t': 1, 'f': 0})
# Out:
# <ipython-input-17-02b13476c36a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   airbnb_sh_df_dna['host_identity_verified'] = airbnb_sh_df_dna['host_identity_verified'].replace({'t': 1, 'f': 0})

# %%
# Encode Availability column
# airbnb_sh_df_dna['has_availability'] = airbnb_sh_df_dna['has_availability'].replace({'t': 1, 'f': 0})

# %%
# Encode Instant Bookable column
airbnb_sh_df_dna['instant_bookable'] = airbnb_sh_df_dna['instant_bookable'].replace({'t': 1, 'f': 0})
# Out:
# <ipython-input-19-1f76a0b049e1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   airbnb_sh_df_dna['instant_bookable'] = airbnb_sh_df_dna['instant_bookable'].replace({'t': 1, 'f': 0})

# %%
# View Updated Data Frame
airbnb_sh_df_dna
# Out:
#        host_response_rate  host_acceptance_rate  host_is_superhost  \
# 0                     100                    98                  1
# 1                       0                     0                  0
# 6                     100                   100                  1
# 7                     100                   100                  1
# 8                     100                   100                  1
# ...                   ...                   ...                ...
# 34034                  89                    99                  0
# 34035                 100                    99                  0
# 34036                 100                    98                  1
# 34038                 100                   100                  0
# 34039                 100                    76                  0
#
#        host_identity_verified  price  review_scores_rating  instant_bookable  \
# 0                           1  175.0                  4.94                 0
# 1                           0  225.0                  4.56                 0
# 6                           0  800.0                  4.82                 1
# 7                           1  500.0                  4.85                 1
# 8                           1  125.0                  4.96                 0
# ...                       ...    ...                   ...               ...
# 34034                       0  288.0                  4.81                 1
# 34035                       1  292.0                  5.00                 0
# 34036                       1  345.0                  5.00                 1
# 34038                       1  600.0                  5.00                 0
# 34039                       1  698.0                  5.00                 1
#
#        reviews_per_month
# 0                   1.41
# 1                   0.09
# 6                   0.51
# 7                   0.91
# 8                   2.74
# ...                  ...
# 34034               1.35
# 34035               0.13
# 34036               1.72
# 34038               0.59
# 34039               0.11
#
# [23548 rows x 8 columns]

# %%
#Look at datatypes
airbnb_sh_df_dna.dtypes
# Out:
# host_response_rate          int64
# host_acceptance_rate        int64
# host_is_superhost           int64
# host_identity_verified      int64
# price                     float64
# review_scores_rating      float64
# instant_bookable            int64
# reviews_per_month         float64
# dtype: object

# %%
# Remove Super Host target from features data
y = airbnb_sh_df_dna.host_is_superhost.values
X = airbnb_sh_df_dna.drop(columns="host_is_superhost").values

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
# Preprocess numerical data for the neural network

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# View X to confirm the data scaled
X
# Out:
# array([[1.00e+02, 9.80e+01, 1.00e+00, ..., 4.94e+00, 0.00e+00, 1.41e+00],
#        [0.00e+00, 0.00e+00, 0.00e+00, ..., 4.56e+00, 0.00e+00, 9.00e-02],
#        [1.00e+02, 1.00e+02, 0.00e+00, ..., 4.82e+00, 1.00e+00, 5.10e-01],
#        ...,
#        [1.00e+02, 9.80e+01, 1.00e+00, ..., 5.00e+00, 1.00e+00, 1.72e+00],
#        [1.00e+02, 1.00e+02, 1.00e+00, ..., 5.00e+00, 0.00e+00, 5.90e-01],
#        [1.00e+02, 7.60e+01, 1.00e+00, ..., 5.00e+00, 1.00e+00, 1.10e-01]])

# %% [markdown]
# # Compile, Train and Evaluate the Model - Attempt 5

# %%
# Define the deep learning model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=20, activation="relu", input_dim=7))
nn_model.add(tf.keras.layers.Dense(units=40, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 552/552 [==============================] - 3s 3ms/step - loss: 0.5892 - accuracy: 0.6894
# Epoch 2/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5573 - accuracy: 0.7135
# Epoch 3/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5475 - accuracy: 0.7227
# Epoch 4/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.5428 - accuracy: 0.7254
# Epoch 5/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.5389 - accuracy: 0.7279
# Epoch 6/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5366 - accuracy: 0.7303
# Epoch 7/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5341 - accuracy: 0.7309
# Epoch 8/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5324 - accuracy: 0.7285
# Epoch 9/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5309 - accuracy: 0.7322
# Epoch 10/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5294 - accuracy: 0.7323
# Epoch 11/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5265 - accuracy: 0.7351
# Epoch 12/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5262 - accuracy: 0.7369
# Epoch 13/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5239 - accuracy: 0.7391
# Epoch 14/50
# 552/552 [==============================] - 2s 4ms/step - loss: 0.5223 - accuracy: 0.7386
# Epoch 15/50
# 552/552 [==============================] - 3s 6ms/step - loss: 0.5212 - accuracy: 0.7382
# Epoch 16/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.5196 - accuracy: 0.7422
# Epoch 17/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5186 - accuracy: 0.7436
# Epoch 18/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5170 - accuracy: 0.7419
# Epoch 19/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5166 - accuracy: 0.7455
# Epoch 20/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5149 - accuracy: 0.7440
# Epoch 21/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5144 - accuracy: 0.7464
# Epoch 22/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5130 - accuracy: 0.7454
# Epoch 23/50
# 552/552 [==============================] - 1s 3ms/step - loss: 0.5118 - accuracy: 0.7468
# Epoch 24/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.5109 - accuracy: 0.7496
# Epoch 25/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5104 - accuracy: 0.7499
# Epoch 26/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5096 - accuracy: 0.7488
# Epoch 27/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5101 - accuracy: 0.7492
# Epoch 28/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5077 - accuracy: 0.7508
# Epoch 29/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5071 - accuracy: 0.7500
# Epoch 30/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5064 - accuracy: 0.7516
# Epoch 31/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5066 - accuracy: 0.7521
# Epoch 32/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5056 - accuracy: 0.7504
# Epoch 33/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5053 - accuracy: 0.7528
# Epoch 34/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.5047 - accuracy: 0.7502
# Epoch 35/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.5038 - accuracy: 0.7527
# Epoch 36/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5028 - accuracy: 0.7536
# Epoch 37/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5025 - accuracy: 0.7527
# Epoch 38/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5026 - accuracy: 0.7526
# Epoch 39/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5005 - accuracy: 0.7552
# Epoch 40/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5006 - accuracy: 0.7541
# Epoch 41/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5007 - accuracy: 0.7541
# Epoch 42/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5006 - accuracy: 0.7543
# Epoch 43/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4993 - accuracy: 0.7556
# Epoch 44/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4989 - accuracy: 0.7580
# Epoch 45/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.4984 - accuracy: 0.7570
# Epoch 46/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.4981 - accuracy: 0.7564
# Epoch 47/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4976 - accuracy: 0.7547
# Epoch 48/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4970 - accuracy: 0.7574
# Epoch 49/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4973 - accuracy: 0.7571
# Epoch 50/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4967 - accuracy: 0.7581
# 184/184 - 1s - loss: 0.5048 - accuracy: 0.7496 - 616ms/epoch - 3ms/step
# Loss: 0.5048128962516785, Accuracy: 0.7496178150177002

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 184/184 - 0s - loss: 0.5048 - accuracy: 0.7496 - 257ms/epoch - 1ms/step
# Loss: 0.5048128962516785, Accuracy: 0.7496178150177002

# %% [markdown]
# # Compile, Train and Evaluate the Model - Attempt 6

# %%
# Define the deep learning model
nn_model2 = tf.keras.models.Sequential()
nn_model2.add(tf.keras.layers.Dense(units=20, activation="relu", input_dim=7))
nn_model2.add(tf.keras.layers.Dense(units=40, activation="relu"))
nn_model2.add(tf.keras.layers.Dense(units=60, activation="relu"))
nn_model2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model2.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 552/552 [==============================] - 3s 2ms/step - loss: 0.5888 - accuracy: 0.6924
# Epoch 2/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5507 - accuracy: 0.7188
# Epoch 3/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5395 - accuracy: 0.7280
# Epoch 4/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5327 - accuracy: 0.7322
# Epoch 5/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5280 - accuracy: 0.7383
# Epoch 6/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5249 - accuracy: 0.7389
# Epoch 7/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5215 - accuracy: 0.7439
# Epoch 8/50
# 552/552 [==============================] - 1s 3ms/step - loss: 0.5183 - accuracy: 0.7444
# Epoch 9/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.5155 - accuracy: 0.7438
# Epoch 10/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.5121 - accuracy: 0.7491
# Epoch 11/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5092 - accuracy: 0.7524
# Epoch 12/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5069 - accuracy: 0.7514
# Epoch 13/50
# 552/552 [==============================] - 1s 3ms/step - loss: 0.5041 - accuracy: 0.7518
# Epoch 14/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5025 - accuracy: 0.7526
# Epoch 15/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4999 - accuracy: 0.7557
# Epoch 16/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4980 - accuracy: 0.7556
# Epoch 17/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4974 - accuracy: 0.7573
# Epoch 18/50
# 552/552 [==============================] - 1s 3ms/step - loss: 0.4941 - accuracy: 0.7579
# Epoch 19/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.4931 - accuracy: 0.7590
# Epoch 20/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.4895 - accuracy: 0.7614
# Epoch 21/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4884 - accuracy: 0.7601
# Epoch 22/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4868 - accuracy: 0.7640
# Epoch 23/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4851 - accuracy: 0.7647
# Epoch 24/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4834 - accuracy: 0.7657
# Epoch 25/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4824 - accuracy: 0.7651
# Epoch 26/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4812 - accuracy: 0.7647
# Epoch 27/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4800 - accuracy: 0.7642
# Epoch 28/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4784 - accuracy: 0.7690
# Epoch 29/50
# 552/552 [==============================] - 2s 4ms/step - loss: 0.4775 - accuracy: 0.7662
# Epoch 30/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.4758 - accuracy: 0.7677
# Epoch 31/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4735 - accuracy: 0.7701
# Epoch 32/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4720 - accuracy: 0.7690
# Epoch 33/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4717 - accuracy: 0.7688
# Epoch 34/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4708 - accuracy: 0.7673
# Epoch 35/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4698 - accuracy: 0.7702
# Epoch 36/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4690 - accuracy: 0.7693
# Epoch 37/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4666 - accuracy: 0.7735
# Epoch 38/50
# 552/552 [==============================] - 1s 3ms/step - loss: 0.4655 - accuracy: 0.7723
# Epoch 39/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.4654 - accuracy: 0.7744
# Epoch 40/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.4634 - accuracy: 0.7742
# Epoch 41/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4616 - accuracy: 0.7748
# Epoch 42/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4612 - accuracy: 0.7731
# Epoch 43/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4607 - accuracy: 0.7736
# Epoch 44/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4591 - accuracy: 0.7761
# Epoch 45/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4588 - accuracy: 0.7742
# Epoch 46/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4554 - accuracy: 0.7774
# Epoch 47/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4556 - accuracy: 0.7759
# Epoch 48/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.4540 - accuracy: 0.7795
# Epoch 49/50
# 552/552 [==============================] - 2s 4ms/step - loss: 0.4534 - accuracy: 0.7772
# Epoch 50/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4539 - accuracy: 0.7800
# 184/184 - 0s - loss: 0.4647 - accuracy: 0.7753 - 367ms/epoch - 2ms/step
# Loss: 0.46470871567726135, Accuracy: 0.7752675414085388

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 184/184 - 0s - loss: 0.4647 - accuracy: 0.7753 - 276ms/epoch - 2ms/step
# Loss: 0.46470871567726135, Accuracy: 0.7752675414085388

# %% [markdown]
# ## Compile, Train and Evaluate the Model - Attempt 7

# %%
# Compile, Train and Evaluate the Model - Attempt 3
number_input_features = X_train.shape[1]
hidden_nodes_layer1 = 50  # Adjusted number of neurons
hidden_nodes_layer2 = 30  # Adjusted number of neurons
hidden_nodes_layer3 = 10 # added extra layer
nn = tf.keras.models.Sequential()
# First hidden layer
# Changed activation to "sigmoid"
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="sigmoid"))
# Second hidden layer
# Changed activation to "sigmoid"
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="sigmoid"))
# Third hidden layer
# Changed activation to "tanh"
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="tanh"))
# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the model
nn.summary()

# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 50)                400
#
#  dense_11 (Dense)            (None, 30)                1530
#
#  dense_12 (Dense)            (None, 10)                310
#
#  dense_13 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 2251 (8.79 KB)
# Trainable params: 2251 (8.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 552/552 [==============================] - 2s 2ms/step - loss: 0.6231 - accuracy: 0.6585
# Epoch 2/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5922 - accuracy: 0.6881
# Epoch 3/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5895 - accuracy: 0.6891
# Epoch 4/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5862 - accuracy: 0.6885
# Epoch 5/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5844 - accuracy: 0.6891
# Epoch 6/100
# 552/552 [==============================] - 2s 3ms/step - loss: 0.5828 - accuracy: 0.6904
# Epoch 7/100
# 552/552 [==============================] - 2s 3ms/step - loss: 0.5796 - accuracy: 0.6908
# Epoch 8/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5750 - accuracy: 0.6911
# Epoch 9/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5722 - accuracy: 0.6929
# Epoch 10/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5684 - accuracy: 0.6966
# Epoch 11/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5671 - accuracy: 0.6970
# Epoch 12/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5650 - accuracy: 0.7000
# Epoch 13/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5635 - accuracy: 0.6998
# Epoch 14/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5625 - accuracy: 0.7006
# Epoch 15/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5611 - accuracy: 0.7035
# Epoch 16/100
# 552/552 [==============================] - 2s 3ms/step - loss: 0.5596 - accuracy: 0.7055
# Epoch 17/100
# 552/552 [==============================] - 2s 3ms/step - loss: 0.5589 - accuracy: 0.7061
# Epoch 18/100
# 552/552 [==============================] - 1s 3ms/step - loss: 0.5578 - accuracy: 0.7065
# Epoch 19/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5576 - accuracy: 0.7065
# Epoch 20/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5563 - accuracy: 0.7065
# Epoch 21/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5554 - accuracy: 0.7077
# Epoch 22/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5550 - accuracy: 0.7075
# Epoch 23/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5532 - accuracy: 0.7113
# Epoch 24/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5525 - accuracy: 0.7104
# Epoch 25/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5514 - accuracy: 0.7156
# Epoch 26/100
# 552/552 [==============================] - 2s 3ms/step - loss: 0.5507 - accuracy: 0.7118
# Epoch 27/100
# 552/552 [==============================] - 2s 3ms/step - loss: 0.5488 - accuracy: 0.7139
# Epoch 28/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5477 - accuracy: 0.7169
# Epoch 29/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5473 - accuracy: 0.7178
# Epoch 30/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5456 - accuracy: 0.7176
# Epoch 31/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5440 - accuracy: 0.7220
# Epoch 32/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5424 - accuracy: 0.7227
# Epoch 33/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5413 - accuracy: 0.7252
# Epoch 34/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5399 - accuracy: 0.7251
# Epoch 35/100
# 552/552 [==============================] - 2s 3ms/step - loss: 0.5391 - accuracy: 0.7249
# Epoch 36/100
# 552/552 [==============================] - 3s 5ms/step - loss: 0.5369 - accuracy: 0.7267
# Epoch 37/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5365 - accuracy: 0.7271
# Epoch 38/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5349 - accuracy: 0.7303
# Epoch 39/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5352 - accuracy: 0.7292
# Epoch 40/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7322
# Epoch 41/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7307
# Epoch 42/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5313 - accuracy: 0.7333
# Epoch 43/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5316 - accuracy: 0.7329
# Epoch 44/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5293 - accuracy: 0.7342
# Epoch 45/100
# 552/552 [==============================] - 2s 4ms/step - loss: 0.5292 - accuracy: 0.7339
# Epoch 46/100
# 552/552 [==============================] - 2s 3ms/step - loss: 0.5286 - accuracy: 0.7344
# Epoch 47/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5276 - accuracy: 0.7357
# Epoch 48/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5266 - accuracy: 0.7338
# Epoch 49/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5271 - accuracy: 0.7364
# Epoch 50/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5254 - accuracy: 0.7361
# Epoch 51/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5246 - accuracy: 0.7352
# Epoch 52/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5244 - accuracy: 0.7359
# Epoch 53/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5231 - accuracy: 0.7376
# Epoch 54/100
# 552/552 [==============================] - 1s 3ms/step - loss: 0.5229 - accuracy: 0.7381
# Epoch 55/100
# 552/552 [==============================] - 2s 4ms/step - loss: 0.5211 - accuracy: 0.7387
# Epoch 56/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5213 - accuracy: 0.7373
# Epoch 57/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5211 - accuracy: 0.7387
# Epoch 58/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5200 - accuracy: 0.7391
# Epoch 59/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5190 - accuracy: 0.7384
# Epoch 60/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5179 - accuracy: 0.7424
# Epoch 61/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5175 - accuracy: 0.7405
# Epoch 62/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5173 - accuracy: 0.7401
# Epoch 63/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5161 - accuracy: 0.7415
# Epoch 64/100
# 552/552 [==============================] - 1s 3ms/step - loss: 0.5156 - accuracy: 0.7419
# Epoch 65/100
# 552/552 [==============================] - 2s 4ms/step - loss: 0.5150 - accuracy: 0.7423
# Epoch 66/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5154 - accuracy: 0.7411
# Epoch 67/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5144 - accuracy: 0.7437
# Epoch 68/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5133 - accuracy: 0.7442
# Epoch 69/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5134 - accuracy: 0.7414
# Epoch 70/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5137 - accuracy: 0.7430
# Epoch 71/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5122 - accuracy: 0.7427
# Epoch 72/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5118 - accuracy: 0.7459
# Epoch 73/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5116 - accuracy: 0.7434
# Epoch 74/100
# 552/552 [==============================] - 2s 4ms/step - loss: 0.5112 - accuracy: 0.7437
# Epoch 75/100
# 552/552 [==============================] - 2s 3ms/step - loss: 0.5111 - accuracy: 0.7438
# Epoch 76/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5091 - accuracy: 0.7448
# Epoch 77/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5107 - accuracy: 0.7420
# Epoch 78/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5105 - accuracy: 0.7446
# Epoch 79/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5091 - accuracy: 0.7447
# Epoch 80/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5086 - accuracy: 0.7475
# Epoch 81/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5086 - accuracy: 0.7464
# Epoch 82/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5080 - accuracy: 0.7471
# Epoch 83/100
# 552/552 [==============================] - 2s 3ms/step - loss: 0.5095 - accuracy: 0.7463
# Epoch 84/100
# 552/552 [==============================] - 2s 4ms/step - loss: 0.5080 - accuracy: 0.7458
# Epoch 85/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5066 - accuracy: 0.7475
# Epoch 86/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5065 - accuracy: 0.7479
# Epoch 87/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5059 - accuracy: 0.7468
# Epoch 88/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5067 - accuracy: 0.7471
# Epoch 89/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5062 - accuracy: 0.7506
# Epoch 90/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5055 - accuracy: 0.7499
# Epoch 91/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5059 - accuracy: 0.7497
# Epoch 92/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5053 - accuracy: 0.7470
# Epoch 93/100
# 552/552 [==============================] - 2s 3ms/step - loss: 0.5044 - accuracy: 0.7497
# Epoch 94/100
# 552/552 [==============================] - 2s 3ms/step - loss: 0.5059 - accuracy: 0.7470
# Epoch 95/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5051 - accuracy: 0.7466
# Epoch 96/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5044 - accuracy: 0.7489
# Epoch 97/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5040 - accuracy: 0.7466
# Epoch 98/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5033 - accuracy: 0.7485
# Epoch 99/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5038 - accuracy: 0.7525
# Epoch 100/100
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5025 - accuracy: 0.7493

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 184/184 - 0s - loss: 0.5040 - accuracy: 0.7461 - 405ms/epoch - 2ms/step
# Loss: 0.5040199756622314, Accuracy: 0.7460505962371826
