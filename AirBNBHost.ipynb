# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# %%
#Read in the csv
airbnb_df = pd.read_csv('listings_clean_nan.csv')
airbnb_df.head()
# Out:
#    Unnamed: 0       source                                               name  \
# 0           0  city scrape   Home in Kapaau · ★4.94 · Studio · 1 bed · 1 bath
# 1           1  city scrape  Rental unit in Pahala · ★4.56 · 2 bedrooms · 2...
# 2           2  city scrape  Cabin in Mountain View · 1 bedroom · 2 beds · ...
# 3           3  city scrape  Home in Kailua-Kona · 2 bedrooms · 3 beds · 1 ...
# 4           4  city scrape  Rental unit in Waikoloa Village · ★New · 1 bed...
#
#      host_id                                     host_url       host_name  \
# 0   31314577   https://www.airbnb.com/users/show/31314577            Marc
# 1   13268454   https://www.airbnb.com/users/show/13268454        Madaline
# 2  251605183  https://www.airbnb.com/users/show/251605183        Kathleen
# 3  504489199  https://www.airbnb.com/users/show/504489199  Kelly And Zain
# 4  336576760  https://www.airbnb.com/users/show/336576760             Tim
#
#   host_since      host_location  host_response_time host_response_rate  ...  \
# 0  4/16/2015         Waimea, HI      within an hour               100%  ...
# 1  3/18/2014  San Francisco, CA  a few days or more                 0%  ...
# 2  3/27/2019     Kurtistown, HI      within an hour               100%  ...
# 3   3/8/2023    Kailua-Kona, HI      within an hour               100%  ...
# 4  2/16/2020   Myrtle Beach, SC  within a few hours                97%  ...
#
#   review_scores_cleanliness review_scores_checkin review_scores_communication  \
# 0                      4.81                   5.0                        4.88
# 1                      4.56                   5.0                        4.78
# 2                       NaN                   NaN                         NaN
# 3                       NaN                   NaN                         NaN
# 4                       NaN                   NaN                         NaN
#
#    review_scores_location  review_scores_value instant_bookable  \
# 0                    4.88                 4.81                f
# 1                    4.33                 4.44                f
# 2                     NaN                  NaN                t
# 3                     NaN                  NaN                f
# 4                     NaN                  NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              4                                           4
# 1                              1                                           1
# 2                              3                                           1
# 3                              3                                           3
# 4                             79                                          79
#
#   calculated_host_listings_count_private_rooms reviews_per_month
# 0                                            0              1.41
# 1                                            0              0.09
# 2                                            2               NaN
# 3                                            0               NaN
# 4                                            0               NaN
#
# [5 rows x 61 columns]

# %%
# Look at the shape
airbnb_df.shape
# Out:
# (34040, 61)

# %%
# Look at what would drop
airbnb_df.dropna().shape
# Out:
# (0, 61)

# %%
# Look at the columns
airbnb_df.columns
# Out:
# Index(['Unnamed: 0', 'source', 'name', 'host_id', 'host_url', 'host_name',
#        'host_since', 'host_location', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_has_profile_pic',
#        'host_identity_verified', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms_text',
#        'bedrooms', 'beds', 'price', 'minimum_nights', 'maximum_nights',
#        'minimum_minimum_nights', 'maximum_minimum_nights',
#        'minimum_maximum_nights', 'maximum_maximum_nights',
#        'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'calendar_updated',
#        'has_availability', 'availability_30', 'availability_60',
#        'availability_90', 'availability_365', 'calendar_last_scraped',
#        'number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
#Create a Data Frame with need columns for ML algorithm
airbnb_sh_df = airbnb_df [['host_response_rate','host_acceptance_rate','host_is_superhost',
            'host_has_profile_pic','host_identity_verified','price',
            'has_availability','review_scores_rating','instant_bookable','reviews_per_month']]
airbnb_sh_df.head()
# Out:
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0               100%                  98%                 t
# 1                 0%                   0%                 f
# 2               100%                  93%                 f
# 3               100%                  97%                 t
# 4                97%                  21%                 t
#
#   host_has_profile_pic host_identity_verified     price has_availability  \
# 0                    t                      t  $175.00                 t
# 1                    t                      f  $225.00                 t
# 2                    t                      t  $100.00                 t
# 3                    t                      t  $102.00                 t
# 4                    t                      t  $209.00                 t
#
#    review_scores_rating instant_bookable  reviews_per_month
# 0                  4.94                f               1.41
# 1                  4.56                f               0.09
# 2                   NaN                t                NaN
# 3                   NaN                f                NaN
# 4                   NaN                f                NaN

# %%
# Look at counts
airbnb_sh_df.count()
# Out:
# host_response_rate        31487
# host_acceptance_rate      32403
# host_is_superhost         34018
# host_has_profile_pic      34038
# host_identity_verified    34038
# price                     32748
# has_availability          32748
# review_scores_rating      25869
# instant_bookable          34040
# reviews_per_month         25858
# dtype: int64

# %%
# Drop NA rows
airbnb_sh_df_dna = airbnb_sh_df.dropna()

# %%
# Look at Counts after dropping NAs
airbnb_sh_df_dna.count()
# Out:
# host_response_rate        23548
# host_acceptance_rate      23548
# host_is_superhost         23548
# host_has_profile_pic      23548
# host_identity_verified    23548
# price                     23548
# has_availability          23548
# review_scores_rating      23548
# instant_bookable          23548
# reviews_per_month         23548
# dtype: int64

# %%
#Look at datatypes
airbnb_sh_df_dna.dtypes
# Out:
# host_response_rate         object
# host_acceptance_rate       object
# host_is_superhost          object
# host_has_profile_pic       object
# host_identity_verified     object
# price                      object
# has_availability           object
# review_scores_rating      float64
# instant_bookable           object
# reviews_per_month         float64
# dtype: object

# %%
# Look at shape
airbnb_sh_df_dna.shape
# Out:
# (23548, 10)

# %%
# Convert host response rate to integer
airbnb_sh_df_dna.host_response_rate = airbnb_sh_df_dna.host_response_rate.str.replace('%','').astype('int')
# Out:
# <ipython-input-45-54c2f90b8817>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   airbnb_sh_df_dna.host_response_rate = airbnb_sh_df_dna.host_response_rate.str.replace('%','').astype('int')

# %%
# Convert host acceptance rate to integer
airbnb_sh_df_dna.host_acceptance_rate = airbnb_sh_df_dna.host_acceptance_rate.str.replace('%','').astype('int')
# Out:
# <ipython-input-46-f5f00195ee1b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   airbnb_sh_df_dna.host_acceptance_rate = airbnb_sh_df_dna.host_acceptance_rate.str.replace('%','').astype('int')

# %%
# Convert price to float
airbnb_sh_df_dna['price'] = airbnb_sh_df_dna['price'].str.replace('$', '').str.replace(',', '').astype('float64')
# Out:
# <ipython-input-47-8c748fc9adf3>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   airbnb_sh_df_dna['price'] = airbnb_sh_df_dna['price'].str.replace('$', '').str.replace(',', '').astype('float64')
# <ipython-input-47-8c748fc9adf3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   airbnb_sh_df_dna['price'] = airbnb_sh_df_dna['price'].str.replace('$', '').str.replace(',', '').astype('float64')

# %%
# Encode Super Host column
airbnb_sh_df_dna['host_is_superhost'] = airbnb_sh_df_dna['host_is_superhost'].replace({'t': 1, 'f': 0})
# Out:
# <ipython-input-48-1100aeae565f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   airbnb_sh_df_dna['host_is_superhost'] = airbnb_sh_df_dna['host_is_superhost'].replace({'t': 1, 'f': 0})

# %%
# Encode Host Profile column
airbnb_sh_df_dna['host_has_profile_pic'] = airbnb_sh_df_dna['host_has_profile_pic'].replace({'t': 1, 'f': 0})
# Out:
# <ipython-input-49-bb34816839dc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   airbnb_sh_df_dna['host_has_profile_pic'] = airbnb_sh_df_dna['host_has_profile_pic'].replace({'t': 1, 'f': 0})

# %%
# Encode Host Identity column
airbnb_sh_df_dna['host_identity_verified'] = airbnb_sh_df_dna['host_identity_verified'].replace({'t': 1, 'f': 0})
# Out:
# <ipython-input-50-a0703802ff92>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   airbnb_sh_df_dna['host_identity_verified'] = airbnb_sh_df_dna['host_identity_verified'].replace({'t': 1, 'f': 0})

# %%
# Encode Availability column
airbnb_sh_df_dna['has_availability'] = airbnb_sh_df_dna['has_availability'].replace({'t': 1, 'f': 0})
# Out:
# <ipython-input-51-93a07731a178>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   airbnb_sh_df_dna['has_availability'] = airbnb_sh_df_dna['has_availability'].replace({'t': 1, 'f': 0})

# %%
# Encode Instant Bookable column
airbnb_sh_df_dna['instant_bookable'] = airbnb_sh_df_dna['instant_bookable'].replace({'t': 1, 'f': 0})
# Out:
# <ipython-input-52-2be8e8afe349>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   airbnb_sh_df_dna['instant_bookable'] = airbnb_sh_df_dna['instant_bookable'].replace({'t': 1, 'f': 0})

# %%
# View Updated Data Frame
airbnb_sh_df_dna
# Out:
#        host_response_rate  host_acceptance_rate  host_is_superhost  \
# 0                     100                    98                  1
# 1                       0                     0                  0
# 6                     100                   100                  1
# 7                     100                   100                  1
# 8                     100                   100                  1
# ...                   ...                   ...                ...
# 34034                  89                    99                  0
# 34035                 100                    99                  0
# 34036                 100                    98                  1
# 34038                 100                   100                  0
# 34039                 100                    76                  0
#
#        host_has_profile_pic  host_identity_verified  price  has_availability  \
# 0                         1                       1  175.0                 1
# 1                         1                       0  225.0                 1
# 6                         1                       0  800.0                 1
# 7                         1                       1  500.0                 1
# 8                         1                       1  125.0                 1
# ...                     ...                     ...    ...               ...
# 34034                     1                       0  288.0                 1
# 34035                     1                       1  292.0                 1
# 34036                     1                       1  345.0                 1
# 34038                     1                       1  600.0                 1
# 34039                     1                       1  698.0                 1
#
#        review_scores_rating  instant_bookable  reviews_per_month
# 0                      4.94                 0               1.41
# 1                      4.56                 0               0.09
# 6                      4.82                 1               0.51
# 7                      4.85                 1               0.91
# 8                      4.96                 0               2.74
# ...                     ...               ...                ...
# 34034                  4.81                 1               1.35
# 34035                  5.00                 0               0.13
# 34036                  5.00                 1               1.72
# 34038                  5.00                 0               0.59
# 34039                  5.00                 1               0.11
#
# [23548 rows x 10 columns]

# %%
#Look at datatypes
airbnb_sh_df_dna.dtypes
# Out:
# host_response_rate          int64
# host_acceptance_rate        int64
# host_is_superhost           int64
# host_has_profile_pic        int64
# host_identity_verified      int64
# price                     float64
# has_availability            int64
# review_scores_rating      float64
# instant_bookable            int64
# reviews_per_month         float64
# dtype: object

# %%
# Remove Super Host target from features data
y = airbnb_sh_df_dna.host_is_superhost.values
X = airbnb_sh_df_dna.drop(columns="host_is_superhost").values

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
# Preprocess numerical data for the neural network

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# View X to confirm the data scaled
X
# Out:
# array([[1.00e+02, 9.80e+01, 1.00e+00, ..., 4.94e+00, 0.00e+00, 1.41e+00],
#        [0.00e+00, 0.00e+00, 1.00e+00, ..., 4.56e+00, 0.00e+00, 9.00e-02],
#        [1.00e+02, 1.00e+02, 1.00e+00, ..., 4.82e+00, 1.00e+00, 5.10e-01],
#        ...,
#        [1.00e+02, 9.80e+01, 1.00e+00, ..., 5.00e+00, 1.00e+00, 1.72e+00],
#        [1.00e+02, 1.00e+02, 1.00e+00, ..., 5.00e+00, 0.00e+00, 5.90e-01],
#        [1.00e+02, 7.60e+01, 1.00e+00, ..., 5.00e+00, 1.00e+00, 1.10e-01]])

# %%
# Define the deep learning model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=20, activation="relu", input_dim=9))
nn_model.add(tf.keras.layers.Dense(units=40, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=60, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 552/552 [==============================] - 3s 3ms/step - loss: 0.5818 - accuracy: 0.6952
# Epoch 2/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5457 - accuracy: 0.7239
# Epoch 3/50
# 552/552 [==============================] - 1s 3ms/step - loss: 0.5361 - accuracy: 0.7309
# Epoch 4/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5304 - accuracy: 0.7359
# Epoch 5/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5270 - accuracy: 0.7373
# Epoch 6/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5246 - accuracy: 0.7390
# Epoch 7/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.5215 - accuracy: 0.7411
# Epoch 8/50
# 552/552 [==============================] - 2s 4ms/step - loss: 0.5200 - accuracy: 0.7428
# Epoch 9/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5181 - accuracy: 0.7443
# Epoch 10/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5158 - accuracy: 0.7463
# Epoch 11/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5136 - accuracy: 0.7467
# Epoch 12/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.5118 - accuracy: 0.7478
# Epoch 13/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.5100 - accuracy: 0.7491
# Epoch 14/50
# 552/552 [==============================] - 1s 3ms/step - loss: 0.5073 - accuracy: 0.7508
# Epoch 15/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.5060 - accuracy: 0.7497
# Epoch 16/50
# 552/552 [==============================] - 2s 4ms/step - loss: 0.5049 - accuracy: 0.7514
# Epoch 17/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.5020 - accuracy: 0.7541
# Epoch 18/50
# 552/552 [==============================] - 1s 3ms/step - loss: 0.5006 - accuracy: 0.7543
# Epoch 19/50
# 552/552 [==============================] - 1s 3ms/step - loss: 0.4987 - accuracy: 0.7566
# Epoch 20/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4965 - accuracy: 0.7551
# Epoch 21/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4962 - accuracy: 0.7576
# Epoch 22/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4939 - accuracy: 0.7585
# Epoch 23/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4927 - accuracy: 0.7564
# Epoch 24/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.4908 - accuracy: 0.7612
# Epoch 25/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.4897 - accuracy: 0.7605
# Epoch 26/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.4888 - accuracy: 0.7613
# Epoch 27/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4870 - accuracy: 0.7625
# Epoch 28/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4857 - accuracy: 0.7610
# Epoch 29/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4842 - accuracy: 0.7636
# Epoch 30/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4827 - accuracy: 0.7658
# Epoch 31/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4807 - accuracy: 0.7663
# Epoch 32/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4798 - accuracy: 0.7637
# Epoch 33/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4775 - accuracy: 0.7652
# Epoch 34/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.4771 - accuracy: 0.7649
# Epoch 35/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.4756 - accuracy: 0.7690
# Epoch 36/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4759 - accuracy: 0.7676
# Epoch 37/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4736 - accuracy: 0.7669
# Epoch 38/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4718 - accuracy: 0.7697
# Epoch 39/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4722 - accuracy: 0.7688
# Epoch 40/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4699 - accuracy: 0.7688
# Epoch 41/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4691 - accuracy: 0.7732
# Epoch 42/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4684 - accuracy: 0.7746
# Epoch 43/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.4662 - accuracy: 0.7721
# Epoch 44/50
# 552/552 [==============================] - 2s 4ms/step - loss: 0.4644 - accuracy: 0.7739
# Epoch 45/50
# 552/552 [==============================] - 2s 3ms/step - loss: 0.4652 - accuracy: 0.7710
# Epoch 46/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4634 - accuracy: 0.7729
# Epoch 47/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4637 - accuracy: 0.7748
# Epoch 48/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4608 - accuracy: 0.7772
# Epoch 49/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4619 - accuracy: 0.7767
# Epoch 50/50
# 552/552 [==============================] - 1s 2ms/step - loss: 0.4610 - accuracy: 0.7752
# 184/184 - 0s - loss: 0.4746 - accuracy: 0.7710 - 400ms/epoch - 2ms/step
# Loss: 0.4745975434780121, Accuracy: 0.7710208892822266

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 184/184 - 0s - loss: 0.4746 - accuracy: 0.7710 - 266ms/epoch - 1ms/step
# Loss: 0.4745975434780121, Accuracy: 0.7710208892822266
